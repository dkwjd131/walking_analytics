# %%
from scipy.signal import find_peaks
import pandas as pd
import matplotlib.pyplot as plt
import scipy.signal as signal
import numpy as np

# %%
df = pd.read_excel('0602_STD2.xlsx', engine='openpyxl')
df2 = df.iloc[377:2083]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1706 entries, 377 to 2082
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    1706 non-null   object
#  1   x_acc   1706 non-null   float64
#  2   y_acc   1706 non-null   float64
#  3   z_acc   1706 non-null   float64
#  4   svm     1706 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 66.8+ KB

# %%
df2 = df2.reset_index(drop=True)

# %%
dfY = df2['y_acc']
peaks, properties = find_peaks(dfY, height=[2,9.1],distance = 40) #,width=0.01 ,prominence=0.01

# %%
plt.figure(figsize = (100,5))
plt.plot(dfY, c = 'b')
plt.plot(peaks, dfY[peaks], "x", c = 'r')

plt.show()
